# %% [markdown]
# #### SESSION - 17

# %% [markdown]
# ##### TASK - 1

# %%
# 1. Create a Python script that imports the math module and uses math.sqrt() to calculate and print the square root of 225.import mathresult = math.sqrt(225)print("square root of 225 is:", result)
# Out:
# square root of 225 is: 15.0

# %% [markdown]
# ##### TASK - 2

# %%
# 2. Write a script that uses the os module to create a new folder named 'MyDownloads' in your current working directory, then print the absolute path of the new folder.import osfolder_name = "MyDownloads"os.makedirs(folder_name, exist_ok=True)print(os.path.abspath(folder_name))
# Out:
# /home/hardik/insta_intro/MyDownloads

# %% [markdown]
# ##### TASK - 3

# %%
# 3. Use the datetime module to get the current date and time, then format and print it as 'DD-MM-YYYY HH:MM:SS', similar to how WhatsApp shows message timestamps.from datetime import datetimenow = datetime.now()formatted_time = now.strftime("%d-%m-%Y %H:%M:%S")print(formatted_time)
# Out:
# 08-09-2026 13:31:26

# %% [markdown]
# ##### TASK - 4

# %%
# 4. Create a custom Python module called playlist_utils.py with a function add_song(playlist, song) that adds a song to a list.%%writefile playlist_utils.pydef add_song(playlist, song):    playlist.append(song)    return playlist
# Out:
# Writing playlist_utils.py

# %%
# Import this module in another script and use it to add three songs to a playlist, then print the final playlist.from playlist_utils import add_songplaylist = []add_song(playlist, "Kesariya")add_song(playlist, "Blinding Lights")add_song(playlist, "Shape of You")print(playlist)
# Out:
# ['Kesariya', 'Blinding Lights', 'Shape of You']

# %% [markdown]
# ##### TASK - 5

# %%
# 5. Set up a new virtual environment using venv, activate it, and install the 'requests' package using pip.# Run these commands in your terminal (not inside a normal code cell):# python -m venv venv_folder# venv_folder\\Scripts\\activate      # on Windows# source venv_folder/bin/activate     # on macOS / Linux# pip install requests

# %%
# Short script that imports requests and prints the version installed.import requestsprint("requests version installed:", requests.__version__)
# Out:
# requests version installed: 2.33.1
